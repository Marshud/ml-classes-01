# %% [markdown]
# <a href="https://colab.research.google.com/github/Marshud/ml-classes-01/blob/main/ML_TrainingandTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Car Mileage Vs Selling Price**

# %%
plt.xlabel('Mileage')
plt.ylabel('Selling Price')
plt.scatter(df['Mileage'], df['Sell Price($)'])

# %% [markdown]
# **Car Age Vs Sell Price($)**

# %%
plt.xlabel('Car Age')
plt.ylabel('Selling Price')
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 11    79000         7
# 8     91000         8
# 14    82450         7
# 0     69000         6
# 17    69000         5
# 12    59000         5
# 13    58780         4
# 18    87600         8
# 6     52000         5
# 15    25400         3
# 2     57000         5
# 9     67000         6
# 3     22500         2
# 16    28000         2
# 7     72000         6
# 5     59000         5

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([16369.27228176, 34240.77323272, 30115.10875874, 27700.4981036 ])

# %%
clf.score(X_test, y_test)
# Out:
# 0.9431669189490358
