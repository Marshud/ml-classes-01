# %% [markdown]
# <a href="https://colab.research.google.com/github/Marshud/ml-classes-01/blob/main/ML_LogisticRegression(BinaryClassification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.scatter(df.age, df.bought_insurance, color='red', marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size=0.9)

# %%
X_test
# Out:
#     age
# 19   18
# 17   58
# 5    56

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.93609793, 0.06390207],
#        [0.08283261, 0.91716739],
#        [0.10432876, 0.89567124]])

# %%
model.predict([[50]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ## Exercise
# Use the dataset [here](https:///kaggle.com/giripujar/hr-analytics)
#
#
# 1.   Observe the data and establish a relationship between other variables and employee retention
# 2.   Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
plt.title('A bar chart for Employee Salary against Retention')
plt.xlabel('Salaries')
plt.ylabel('Retention')
plt.bar(df.salary, df.left)
# Out:
# <BarContainer object of 14999 artists>

# %%
plt.title('A bar chart showing correlation between department and employee retention')
plt.xlabel('Departments')
plt.ylabel('Retention')
plt.barh(df.Department, df.left)
# Out:
# <BarContainer object of 14999 artists>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years']], df.left, train_size=0.50)

# %%
X_train
# Out:
#        last_evaluation  number_project  average_montly_hours  \
# 600               0.98               5                   259
# 14920             0.91               5                   228
# 2498              0.52               2                   105
# 668               0.92               6                   258
# 2698              0.47               4                   176
# ...                ...             ...                   ...
# 7403              0.63               3                   162
# 2408              0.88               4                   213
# 11730             0.58               3                   220
# 12418             0.53               3                   199
# 10281             0.37               3                   169
#
#        time_spend_company  Work_accident  promotion_last_5years
# 600                     6              0                      0
# 14920                   5              0                      0
# ...

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.7504
